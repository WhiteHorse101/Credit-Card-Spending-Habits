# %% [markdown]
# # Credit Card Spending Habits in India

# %% [markdown]
# This dataset contains insights into a collection of credit card transactions made in India, offering a comprehensive look at the spending habits of Indians across the nation. From the Gender and Card type used to carry out each transaction, to which city saw the highest amount of spending and even what kind of expenses were made, this dataset paints an overall picture about how money is being spent in India today. With its variety in variables, researchers have an opportunity to uncover deeper trends in customer spending as well as interesting correlations between data points that can serve as invaluable business intelligence. Whether you're interested in learning more about customer preferences or simply exploring unbiased data analysis techniques, this data is sure to provide insight beyond what one could anticipate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Credit card transactions - India - Simple.csv')

# %%
data.head(25)
# Out:
#     index                   City       Date  Card Type Exp Type Gender  Amount
# 0       0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1       1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2       2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3       3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4       4       Bengaluru, India   5-May-15       Gold    Bills      F  171574
# 5       5           Delhi, India   8-Sep-14     Silver    Bills      F  100036
# 6       6           Delhi, India  24-Feb-15       Gold    Bills      F  143250
# 7       7  Greater Mumbai, India  26-Jun-14   Platinum    Bills      F  150980
# 8       8           Delhi, India  28-Mar-14     Silver    Bills      F  192247
# 9       9           Delhi, India   1-Sep-14   Platinum    Bills      F   67932
# 10     10           Delhi, India  22-Jun-14   Platinum    Bills      F  280061
# ...

# %%
data.tail(25)
# Out:
#        index              City       Date  Card Type Exp Type Gender  Amount
# 26027  26027    Kolkata, India  23-Nov-14  Signature   Travel      M  136863
# 26028  26028    Lucknow, India  20-Nov-13     Silver   Travel      F  263420
# 26029  26029     Kanpur, India   1-Jan-15   Platinum   Travel      M  224671
# 26030  26030    Lucknow, India  20-Jul-14     Silver   Travel      M  123503
# 26031  26031     Kanpur, India   7-Jul-14  Signature   Travel      M  262233
# 26032  26032     Kanpur, India   4-Feb-15   Platinum   Travel      F   20961
# 26033  26033     Jaipur, India   1-Oct-14   Platinum   Travel      F  286104
# 26034  26034     Kanpur, India   2-Dec-14   Platinum   Travel      F  178865
# 26035  26035       Pune, India   4-Jul-14  Signature   Travel      M  266219
# 26036  26036     Kanpur, India  28-Jul-14   Platinum   Travel      F   92560
# 26037  26037  Hyderabad, India  19-Jun-14  Signature   Travel      M    6875
# ...

# %%
print('number of missing data:')
print(data.isnull().sum())
# Out:
# number of missing data:
# index        0
# City         0
# Date         0
# Card Type    0
# Exp Type     0
# Gender       0
# Amount       0
# dtype: int64

# %%
data.groupby('Gender').count()
# Out:
#         index   City   Date  Card Type  Exp Type  Amount
# Gender
# F       13680  13680  13680      13680     13680   13680
# M       12372  12372  12372      12372     12372   12372

# %%
data.groupby('Card Type').count()
# Out:
#            index  City  Date  Exp Type  Gender  Amount
# Card Type
# Gold        6367  6367  6367      6367    6367    6367
# Platinum    6398  6398  6398      6398    6398    6398
# Signature   6447  6447  6447      6447    6447    6447
# Silver      6840  6840  6840      6840    6840    6840

# %%
data.groupby('Exp Type').count()
# Out:
#                index  City  Date  Card Type  Gender  Amount
# Exp Type
# Bills           5078  5078  5078       5078    5078    5078
# Entertainment   4762  4762  4762       4762    4762    4762
# Food            5463  5463  5463       5463    5463    5463
# Fuel            5257  5257  5257       5257    5257    5257
# Grocery         4754  4754  4754       4754    4754    4754
# Travel           738   738   738        738     738     738

# %%
Delhi = data.loc[data['City'] == 'Delhi, India']
Mumbai = data.loc[data['City'] == 'Greater Mumbai, India']
Kolkata = data.loc[data['City'] == 'Kolkata, India']

# %%
Delhi.head(25)
# Out:
#     index          City       Date  Card Type Exp Type Gender  Amount
# 0       0  Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 5       5  Delhi, India   8-Sep-14     Silver    Bills      F  100036
# 6       6  Delhi, India  24-Feb-15       Gold    Bills      F  143250
# 8       8  Delhi, India  28-Mar-14     Silver    Bills      F  192247
# 9       9  Delhi, India   1-Sep-14   Platinum    Bills      F   67932
# 10     10  Delhi, India  22-Jun-14   Platinum    Bills      F  280061
# 13     13  Delhi, India  27-Apr-14  Signature    Bills      F  254359
# 20     20  Delhi, India   4-Apr-14  Signature    Bills      F  366102
# 21     21  Delhi, India   1-Jul-14  Signature    Bills      F  809623
# 25     25  Delhi, India  27-Sep-14     Silver    Bills      F  622170
# 29     29  Delhi, India  18-Apr-15       Gold    Bills      F  702774
# 39     39  Delhi, India   3-Feb-15     Silver    Bills      F  401351
# ...

# %%
Delhi.tail(25)
# Out:
#        index          City       Date  Card Type       Exp Type Gender  Amount
# 13897  13897  Delhi, India  28-Apr-14  Signature        Grocery      M   11927
# 13902  13902  Delhi, India   9-Nov-13     Silver          Bills      F  195444
# 13903  13903  Delhi, India  31-Jul-14       Gold           Fuel      F   68847
# 13911  13911  Delhi, India  14-Apr-14     Silver        Grocery      F  145769
# 13914  13914  Delhi, India  15-Aug-14  Signature        Grocery      F  293794
# 13917  13917  Delhi, India   4-Apr-14       Gold           Fuel      M   80596
# 13918  13918  Delhi, India  15-May-15  Signature        Grocery      F   18179
# 13919  13919  Delhi, India  12-Aug-14  Signature  Entertainment      F  231765
# 13922  13922  Delhi, India  30-Mar-14       Gold          Bills      F  182038
# 13925  13925  Delhi, India  29-Jun-14       Gold        Grocery      F  248672
# 13927  13927  Delhi, India   4-Jan-15     Silver        Grocery      F  110292
# ...

# %%
Delhi['Card Type'].value_counts(normalize=True) * 100
# Out:
# Silver       27.455485
# Signature    25.043079
# Gold         24.784607
# Platinum     22.716829
# Name: Card Type, dtype: float64

# %%
Mumbai['Card Type'].value_counts(normalize=True) * 100
# Out:
# Silver       27.397652
# Platinum     24.849699
# Gold         24.277126
# Signature    23.475522
# Name: Card Type, dtype: float64

# %%
Kolkata['Card Type'].value_counts(normalize=True)*100
# Out:
# Platinum     25.873221
# Silver       25.355757
# Signature    24.450194
# Gold         24.320828
# Name: Card Type, dtype: float64

# %% [markdown]
# We can see there is not drastic difference between percent of distribution of different Card Types
# But we see 2% increase in Platinum type card holder in Mumbai & at the same time 2% drop in Signature type card holder

# %%
Mumbai.head(15)
# Out:
#     index                   City       Date  Card Type Exp Type Gender  Amount
# 1       1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 3       3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 7       7  Greater Mumbai, India  26-Jun-14   Platinum    Bills      F  150980
# 11     11  Greater Mumbai, India   7-Dec-13  Signature    Bills      F  278036
# 12     12  Greater Mumbai, India   7-Aug-14       Gold    Bills      F   19226
# 14     14  Greater Mumbai, India  15-Aug-14  Signature    Bills      F  302834
# 15     15  Greater Mumbai, India  28-Nov-14   Platinum    Bills      F  647116
# 16     16  Greater Mumbai, India  14-Jun-14  Signature    Bills      F  421878
# 17     17  Greater Mumbai, India  30-Mar-15       Gold    Bills      F  986379
# 18     18  Greater Mumbai, India  15-Mar-14   Platinum    Bills      F  213047
# 19     19  Greater Mumbai, India   9-Nov-13   Platinum    Bills      F  735566
# ...

# %%
Mumbai.tail(10)
# Out:
#        index                   City       Date  Card Type       Exp Type  \
# 13979  13979  Greater Mumbai, India  28-Nov-13  Signature           Fuel
# 13986  13986  Greater Mumbai, India  25-Oct-13  Signature           Fuel
# 13995  13995  Greater Mumbai, India  28-Dec-14     Silver           Food
# 14276  14276  Greater Mumbai, India  28-Sep-14       Gold  Entertainment
# 14837  14837  Greater Mumbai, India  21-Sep-14  Signature           Food
# 15233  15233  Greater Mumbai, India   8-Nov-14       Gold          Bills
# 15800  15800  Greater Mumbai, India  31-Jul-14  Signature          Bills
# 16208  16208  Greater Mumbai, India  12-Mar-15   Platinum           Food
# 16296  16296  Greater Mumbai, India   9-Mar-14       Gold        Grocery
# 17057  17057  Greater Mumbai, India  11-Feb-15  Signature          Bills
#
#       Gender  Amount
# 13979      F  127292
# 13986      M  257510
# 13995      M  180317
# 14276      F  159417
# 14837      M  272796
# 15233      M  117492
# ...

# %%
Mumbai['Card Type'].value_counts(normalize=True) * 100
# Out:
# Silver       27.397652
# Platinum     24.849699
# Gold         24.277126
# Signature    23.475522
# Name: Card Type, dtype: float64

# %%
Mumbai['Gender'].value_counts(normalize=True) * 100
# Out:
# F    55.024334
# M    44.975666
# Name: Gender, dtype: float64

# %%
Delhi['Gender'].value_counts(normalize=True)*100
# Out:
# F    55.226881
# M    44.773119
# Name: Gender, dtype: float64

# %%
Kolkata.head()
# Out:
#        index            City       Date  Card Type       Exp Type Gender  \
# 14863  14863  Kolkata, India  24-Nov-14     Silver           Fuel      M
# 16486  16486  Kolkata, India  10-Sep-14       Gold           Food      F
# 16845  16845  Kolkata, India  14-Aug-14     Silver  Entertainment      F
# 18202  18202  Kolkata, India  26-Nov-13     Silver  Entertainment      M
# 19030  19030  Kolkata, India   4-Nov-14  Signature  Entertainment      M
#
#        Amount
# 14863   92218
# 16486   68737
# 16845  101610
# 18202   33596
# 19030  238026

# %%
Kolkata.tail()
# Out:
#        index            City       Date  Card Type Exp Type Gender  Amount
# 26021  26021  Kolkata, India  13-Jun-14     Silver   Travel      M  183853
# 26027  26027  Kolkata, India  23-Nov-14  Signature   Travel      M  136863
# 26044  26044  Kolkata, India  14-Oct-14       Gold   Travel      M  243249
# 26045  26045  Kolkata, India  26-Feb-14  Signature   Travel      F  170049
# 26047  26047  Kolkata, India  22-Jun-14     Silver   Travel      F  128191

# %%
Kolkata['Gender'].value_counts(normalize=True)*100
# Out:
# M    51.875809
# F    48.124191
# Name: Gender, dtype: float64

# %%
Kolkata['Card Type'].value_counts(normalize= True)*100
# Out:
# Platinum     25.873221
# Silver       25.355757
# Signature    24.450194
# Gold         24.320828
# Name: Card Type, dtype: float64

# %%
Delhi['Card Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Mumbai['Card Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Kolkata['Card Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above drawn Bar Graphs we can see Mumbai & Delhi have almost similar trend in card holders but in Kolkata we can there is not a noticiable drop between different types of card holders they are more or less the same & another shocking revelation is Gold users are the least in Kolkata
